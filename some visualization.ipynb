# %%
import pandas as pd

df = pd.read_parquet("hf://datasets/Adelante/arabic-qa-largebatch/data/train-00000-of-00001.parquet")

# %%
df
# Out:
#        year  month  date  page  slice  \
# 0      2010     12     1     1      1
# 1      2010     12     1     1      2
# 2      2010     12     1     2      2
# 3      2010     12     1     2      3
# 4      2010     12     1     2      5
# ...     ...    ...   ...   ...    ...
# 28235  2011     12    31    21      5
# 28236  2011     12    31    21      6
# 28237  2011     12    31    21      7
# 28238  2011     12    31    22      1
# 28239  2011     12    31    22      3
#
#                                                     text  \
# 0      \nسه. .سد ٠٢٨٠،\n٢٠سضسجة ١٤٣١ ه-١سبر (صناول)٢ ...
# 1       عنى النتيجة\nوعنى جانب اخر اعرب مجلس الوزرا، ...
# 2      ***** فرعود الذمى\nيومبا رحلات الغذاء\nمع النح...
# 3      ان اللجنة حرحت عنى تنفيذ القانون والاحكام\nالف...
# 4      ممعرية ومحطات التليفزيون\nالمحلية والغضانية\nا...
# ...                                                  ...
# 28235   عام ٢٠١١\n- أض رفيع نحدث عن آسدا ب ارتفاع معد...
# 28236  أن بوابر [ ازسات ند بدأت مالفكل فى الظهير معد ...
# 28237  ى نطاهات\nسوى الثمعير بالأمن. مشيرا إر أمها أص...
# 28238  اسه ٣١ ديسمبر ٢٠١١\n1\nاسل ١٠:٣/٢٢/؛\nالثور٢١/...
# 28239  الت الأم إنها ذهلت عندما\nلاحظت احتفا ، ولدها ...
#
#                                               containing 问题1-数字 问题2-数字 问题3-数字  \
# 0      [{'ar': 'انتخابات', 'zh': '选举'}, {'ar': 'العدا...      4      6      7
# 1      [{'ar': 'انتخابات', 'zh': '选举'}, {'ar': 'الرئي...      3      6      1
# 2      [{'ar': 'انتخابات', 'zh': '选举'}, {'ar': 'العدا...      3      6      7
# 3      [{'ar': 'انتخابات', 'zh': '选举'}, {'ar': 'الرئي...      3      6      1
# 4      [{'ar': 'الدستور', 'zh': '宪法'}, {'ar': 'سلطة',...      4      6      7
# ...                                                  ...    ...    ...    ...
# 28235  [{'ar': 'الشرطة', 'zh': '警察'}, {'ar': 'ثورة', ...      1      1      2
# 28236  [{'ar': 'الشرطة', 'zh': '警察'}, {'ar': 'الشباب'...      3      1      2
# 28237  [{'ar': 'ثورة', 'zh': '革命'}, {'ar': 'فساد', 'z...      3      2      1
# 28238  [{'ar': 'انتخابات', 'zh': '选举'}, {'ar': 'ثورة'...      3      1      2
# 28239  [{'ar': 'الشباب', 'zh': '青年'}, {'ar': 'ديمقراط...      3      1      2
#
#        ... 问题9-数字 问题1-文字   问题2-文字   问题3-文字 问题4-文字     问题5-文字     问题6-文字  \
# 0      ...      2     中立       选举       其他     其他  经济改革与政策调整         其他
# 1      ...      2   中度负面       选举  失业与经济困境     其他         其他    法律与宪法改革
# 2      ...      2   中度负面       选举       其他     其他         其他         其他
# 3      ...      2   中度负面       选举  失业与经济困境     其他  经济改革与政策调整    法律与宪法改革
# 4      ...      2     中立       选举       其他     其他  国家安全与社会稳定  经济改革与政策调整
# ...    ...    ...    ...      ...      ...    ...        ...        ...
# 28235  ...      4   极其负面  失业与经济困境  社会不公与腐败     其他  国家安全与社会稳定  经济改革与政策调整
# 28236  ...      4   中度负面  失业与经济困境  社会不公与腐败     其他  国家安全与社会稳定  经济改革与政策调整
# 28237  ...      4   中度负面  社会不公与腐败  失业与经济困境     其他    法律与宪法改革  国家安全与社会稳定
# 28238  ...      4   中度负面  失业与经济困境  社会不公与腐败     其他  国家安全与社会稳定  经济改革与政策调整
# 28239  ...      2   中度负面  失业与经济困境  社会不公与腐败     其他  经济改革与政策调整    法律与宪法改革
#
#           问题7-文字     问题8-文字 问题9-文字
# 0             其他  政府部门及政府官员      低
# 1      经济改革与政策调整  政府部门及政府官员      低
# 2             其他  政府部门及政府官员      低
# 3             其他  政府部门及政府官员      低
# 4             其他  政府部门及政府官员      低
# ...          ...        ...    ...
# 28235         其他  政府部门及政府官员      高
# 28236         其他  政府部门及政府官员      高
# 28237         其他  政府部门及政府官员      高
# 28238         其他  政府部门及政府官员      高
# 28239         其他  政府部门及政府官员      低
#
# [28240 rows x 25 columns]

# %% [markdown]
# # Analysis 1
# 在某情感下的主题分布

# %%
sentiment = '中度正面'
subdf = df[df['问题1-文字'] == sentiment]
print(f"情感为{sentiment}时，民生部分主题分布：")
for theme in set(df['问题3-文字']):
    if theme == '0':
        continue
    cnt = (subdf['问题2-文字'].tolist().count(theme))
    if len(theme) < 5:
        theme += "     "
    print(theme,'\t',cnt,'\t/',len(subdf),' = ',int(cnt/len(subdf)*1000) / 10,'%')
# Out:
# 情感为中度正面时，民生部分主题分布：
# 埃及革命      	 3 	/ 222  =  1.3 %
# 基本公共服务缺失 	 9 	/ 222  =  4.0 %
# 失业与经济困境 	 125 	/ 222  =  56.3 %
# 其他      	 44 	/ 222  =  19.8 %
# 社会不公与腐败 	 2 	/ 222  =  0.9 %
# 选举      	 25 	/ 222  =  11.2 %
# 人权与自由 	 14 	/ 222  =  6.3 %

# %% [markdown]
# # Analysis 2
# 在某主题下的情感分布

# %%
theme = '埃及革命'
subdf = df[df['问题2-文字'] == theme]
print(f"主题为{theme}时，情感分布：")
for sentiment in set(df['问题1-文字']):
    if sentiment == '0':
        continue
    cnt = (subdf['问题1-文字'].tolist().count(sentiment))
    if len(sentiment) == 2:
        sentiment += '    '
    print(sentiment,'\t',cnt,'\t/',len(subdf),' = ',int(cnt/len(subdf)*1000) / 10,'%')
# Out:
# 主题为埃及革命时，情感分布：
# 强烈负面 	 60 	/ 2118  =  2.8 %
# 中度正面 	 3 	/ 2118  =  0.1 %
# 中立     	 83 	/ 2118  =  3.9 %
# 中度负面 	 887 	/ 2118  =  41.8 %
# 极其负面 	 1078 	/ 2118  =  50.8 %
# 强烈正面 	 7 	/ 2118  =  0.3 %

# %% [markdown]
# # Analysis 3
# 关键词共现 co-occurrence

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# 提取所有关键词
all_keywords = sorted(set(keyword['zh'] for sublist in df['containing'] for keyword in sublist))
print(all_keywords, len(all_keywords))
# 初始化共现矩阵
co_occurrence_matrix = pd.DataFrame(0, index=all_keywords, columns=all_keywords)

# 填充共现矩阵
for sublist in tqdm(df['containing']):
    for i in range(len(sublist)):
        for j in range(i+1, len(sublist)):
            co_occurrence_matrix.loc[sublist[i]['zh'], sublist[j]['zh']] += 1
            co_occurrence_matrix.loc[sublist[j]['zh'], sublist[i]['zh']] += 1

# 自己与自己共现次数为总数
for keyword in tqdm(all_keywords):
    co_occurrence_matrix.loc[keyword, keyword] = sum(keyword in sublist for sublist in df['containing'])
# Out:
# ['价格', '养老金', '动荡', '医院', '反对派', '团结', '大学', '失业', '安全', '宪法', '工人', '广场', '总统', '抗议', '抵抗', '改革', '政变', '政治', '暴力', '权利', '权力', '正义', '民主', '民族团结', '法院', '烈士', '独立', '示威', '社会公正', '种族的', '紧急状态', '罢工', '联盟', '腐败', '自由', '自由与正义', '警察', '贫穷', '起义', '选举', '通胀', '通货膨胀', '青年', '面包', '革命', '革命青年', '骚乱'] 47
# 100%|███████████████████████████████████████████████████████████████████████████| 28240/28240 [00:29<00:00, 958.52it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 47/47 [00:03<00:00, 12.90it/s]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

ax = sns.heatmap(co_occurrence_matrix, annot=False, cmap="YlGnBu", xticklabels=True, yticklabels=True)
plt.title("关键词共现热力图")

# 旋转x轴和y轴标签
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, fontsize=5)  # 旋转x轴标签，字体大小8
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=5)   # 保持y轴标签垂直，字体大小8

# 设置热力图大小
plt.figure(figsize=(200, 160),dpi=2000)

# 设置中文字体（假设你有一个支持中文的字体文件路径，如 'SimHei.ttf'）
plt.rcParams['font.family'] = 'Microsoft YaHei'

plt.show()

# %%
import plotly.express as px
import numpy as np
import pandas as pd

# 使用 Plotly 绘制热力图
fig = px.imshow(co_occurrence_matrix, labels=dict(x="关键词", y="关键词", color="共现频次"), color_continuous_scale=['#39C5BB',"#0000FF"])

# 更新布局以增强交互性
fig.update_xaxes(side="top")  # 将x轴放在顶部
fig.update_layout(
    title="关键词共现关系热力图",
    xaxis_nticks=47,  # 确保显示所有x轴标签
    yaxis_nticks=47,  # 确保显示所有y轴标签
    autosize=False,
    width=800,  # 图像宽度
    height=800,  # 图像高度
)

fig.show()
fig.write_html("heatmap.html")
# Out:
# <div>                            <div id="089ef45b-631a-414a-b5b9-680fa4d11b2d" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("089ef45b-631a-414a-b5b9-680fa4d11b2d")) {                    Plotly.newPlot(                        "089ef45b-631a-414a-b5b9-680fa4d11b2d",                        [{"coloraxis":"coloraxis","name":"0","x":["\u4ef7\u683c","\u517b\u8001\u91d1","\u52a8\u8361","\u533b\u9662","\u53cd\u5bf9\u6d3e","\u56e2\u7ed3","\u5927\u5b66","\u5931\u4e1a","\u5b89\u5168","\u5baa\u6cd5","\u5de5\u4eba","\u5e7f\u573a","\u603b\u7edf","\u6297\u8bae","\u62b5\u6297","\u6539\u9769","\u653f\u53d8","\u653f\u6cbb","\u66b4\u529b","\u6743\u5229","\u6743\u529b","\u6b63\u4e49","\u6c11\u4e3b","\u6c11\u65cf\u56e2\u7ed3","\u6cd5\u9662","\u70c8\u58eb","\u72ec\u7acb","\u793a\u5a01","\u793e\u4f1a\u516c\u6b63","\u79cd\u65cf\u7684","\u7d27\u6025\u72b6\u6001","\u7f62\u5de5","\u8054\u76df","\u8150\u8d25","\u81ea\u7531","\u81ea\u7531\u4e0e\u6b63\u4e49","\u8b66\u5bdf","\u8d2b\u7a77","\u8d77\u4e49","\u9009\u4e3e","\u901a\u80c0","\u901a\u8d27\u81a8\u80c0","\u9752\u5e74","\u9762\u5305","\u9769\u547d","\u9769\u547d\u9752\u5e74","\u9a9a\u4e71"],"y":["\u4ef7\u683c","\u517b\u8001\u91d1","\u52a8\u8361","\u533b\u9662","\u53cd\u5bf9\u6d3e","\u56e2\u7ed3","\u5927\u5b66","\u5931\u4e1a","\u5b89\u5168","\u5baa\u6cd5","\u5de5\u4eba","\u5e7f\u573a","\u603b\u7edf","\u6297\u8bae","\u62b5\u6297","\u6539\u9769","\u653f\u53d8","\u653f\u6cbb","\u66b4\u529b","\u6743\u5229","\u6743\u529b","\u6b63\u4e49","\u6c11\u4e3b","\u6c11\u65cf\u56e2\u7ed3","\u6cd5\u9662","\u70c8\u58eb","\u72ec\u7acb","\u793a\u5a01","\u793e\u4f1a\u516c\u6b63","\u79cd\u65cf\u7684","\u7d27\u6025\u72b6\u6001","\u7f62\u5de5","\u8054\u76df","\u8150\u8d25","\u81ea\u7531","\u81ea\u7531\u4e0e\u6b63\u4e49","\u8b66\u5bdf","\u8d2b\u7a77","\u8d77\u4e49","\u9009\u4e3e","\u901a\u80c0","\u901a\u8d27\u81a8\u80c0","\u9752\u5e74","\u9762\u5305","\u9769\u547d","\u9769\u547d\u9752\u5e74","\u9a9a\u4e71"],"z":[[0,8,20,16,23,27,16,57,72,27,74,48,41,40,6,62,0,30,29,23,40,99,38,3,29,4,2,55,46,5,0,17,14,152,44,1,67,97,5,68,39,44,65,20,128,5,6],[8,0,5,9,12,33,31,37,28,45,93,69,52,47,6,54,0,24,28,20,62,86,42,0,35,11,5,72,36,7,1,21,6,152,59,9,72,60,2,90,13,16,72,8,136,11,18],[20,5,0,19,119,13,39,76,122,62,79,132,158,172,15,188,9,97,185,15,217,130,140,7,57,4,28,164,26,20,9,25,51,278,151,20,154,109,26,225,29,37,102,15,264,3,53],[16,9,19,0,54,19,57,38,183,57,69,244,130,60,12,123,6,40,95,22,112,124,62,17,70,17,5,226,28,13,9,24,27,231,106,13,237,144,9,122,6,9,189,9,258,21,55],[23,12,119,54,0,34,60,49,366,275,124,363,575,357,72,496,55,225,394,52,804,267,429,50,68,10,19,571,50,67,13,40,201,575,310,20,328,163,102,720,14,20,366,11,554,33,50],[27,33,13,19,34,0,55,42,95,42,83,139,103,85,18,127,0,40,79,31,86,311,109,16,37,15,12,114,188,14,0,10,35,181,109,32,127,125,5,142,7,11,183,45,207,15,32],[16,31,39,57,60,55,0,80,138,138,174,190,176,116,21,262,17,152,144,69,228,217,178,24,79,12,36,201,57,33,1,8,35,461,189,25,206,149,11,372,19,31,398,9,479,22,40],[57,37,76,38,49,42,80,0,143,100,230,163,225,139,16,228,13,140,131,36,227,296,215,6,56,12,13,182,107,30,1,27,56,583,217,40,202,572,24,317,65,83,423,18,387,15,29],[72,28,122,183,366,95,138,143,0,316,258,950,766,471,97,647,59,329,751,144,900,602,509,56,330,53,45,1152,119,88,40,45,187,974,619,96,1585,342,77,998,21,40,808,54,1258,104,222],[27,45,62,57,275,42,138,100,316,0,308,568,614,234,35,701,52,366,351,296,1232,779,898,46,280,43,81,537,131,62,27,30,266,1196,822,159,556,309,39,1472,16,28,613,12,1542,101,64],[74,93,79,69,124,83,174,230,258,308,0,377,363,289,48,426,37,205,227,118,498,647,403,30,133,28,24,435,109,44,9,134,192,886,590,205,513,326,25,887,45,54,545,17,890,68,88],[48,69,132,244,363,139,190,163,950,568,377,0,827,621,101,1171,56,398,867,151,1292,1015,937,70 ...
